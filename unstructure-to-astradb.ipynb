# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# import logging
# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)

# %%
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT")
ASTRA_DB_DATABASE_ID = os.getenv("ASTRA_DB_DATABASE_ID")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN")
ASTRA_DB_KEYSPACE = os.getenv("ASTRA_DB_KEYSPACE")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_astradb import AstraDBVectorStore

vector_store = AstraDBVectorStore(
    collection_name="unstructure_elements",
    embedding=embeddings,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE,
)

# %%
from langchain_core.documents import Document
from unstructured.documents.elements import Element
def element_to_document(element: Element) -> Document:
    return Document(
        id=element.id,
        page_content=element.text,
        metadata={
            "type": type(element).__name__,
            "links": [],
            **element.metadata.to_dict(),
        },
    )

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf(
    filename="./data/sample4.pdf",
    extract_images_in_pdf=True,
    infer_table_structure=True,
    max_characters=2000,
    new_after_n_chars=1700,
    extract_image_block_output_dir="images/",
)

# %%
docs = []
for element in elements:
        try:
            element_type = type(element).__name__
            doc = element_to_document(element)
            docs.append(doc)
        except Exception as e:
            print(
                f"An error occurred while processing element {element.id}: {e}"
            )
            break

# %%
vector_store.add_documents(docs)
# Out:
# ['8a137031615c0f20b771cfe3956d57f8',
#  '3579e20ad32d793a8dd28ff5d8023da7',
#  '80e8c329a3a621b91a31bcf97ff3334f',
#  '35ccf72b73f67342fb97284be07e0de1',
#  '39324654c968eb3357caf516e5f7f294',
#  'e6cd9de5667b301da81d1373f90e734c',
#  '935fdcf8ba2e601348691f23784106a0',
#  '002f87c6560b4f412ee064375b00319d',
#  '2c3e32aafc4e37c57c9299bb1abe8cf3',
#  'c350ce92d1a85844e3195a7f97174afb',
#  'c20e14a2e6cc3abd9e3794c19db89c4e',
#  'bc5e09f692d6cf4ac05d9e6d84ecf9ca',
#  '73c2a9d151deb9c8f6b1113cb8faad74',
#  'b58ded2c0d09fcd6b1810df1f7cd9423',
#  '0c6140c07f5c2e92399007e8c762c4cb',
#  'b5906a2b13ee1bbfb62f054bd10f61f2',
#  'ae823f07134a0ee9e668bef86d2caa08',
#  '4836a5c73aaa4ee24183d49ebc83390f',
#  'ec4e566681062b3415e6e140502beb8b',
#  '441d6021d20dac79ddd32d9e17568dc8',
#  'b7cdb0075e34409ff9418ff94b025d74']

# %%
[doc for doc in vector_store.astra_env.collection.find({})]
# Out:
# [{'_id': 'b7cdb0075e34409ff9418ff94b025d74',
#   'content': '',
#   'metadata': {'type': 'Image',
#    'links': [],
#    'coordinates': {'points': [[-2.083333333333333, 1966.6666666666665],
#      [-2.083333333333333, 2200.0],
#      [1702.0833333333333, 2200.0],
#      [1702.0833333333333, 1966.6666666666665]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'image_path': 'images/figure-2-5.jpg',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '35ccf72b73f67342fb97284be07e0de1',
#   'content': 'Product Brochure',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.6584488749504089,
#    'coordinates': {'points': [[195.39285278320312, 411.7275390625],
#      [195.39285278320312, 513.0299504884981],
#      [937.9750366210938, 513.0299504884981],
#      [937.9750366210938, 411.7275390625]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '0c6140c07f5c2e92399007e8c762c4cb',
#   'content': '',
#   'metadata': {'type': 'Image',
#    'links': [],
#    'coordinates': {'points': [[-2.083333333333333, 1968.75],
#      [-2.083333333333333, 2202.083333333333],
#      [1702.0833333333333, 2202.083333333333],
#      [1702.0833333333333, 1968.75]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'image_path': 'images/figure-1-3.jpg',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '2c3e32aafc4e37c57c9299bb1abe8cf3',
#   'content': '',
#   'metadata': {'type': 'Image',
#    'links': [],
#    'coordinates': {'points': [[200.0, 952.0832777777778],
#      [200.0, 1562.5],
#      [735.416611111111, 1562.5],
#      [735.416611111111, 952.0832777777778]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'image_path': 'images/figure-1-2.jpg',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'b58ded2c0d09fcd6b1810df1f7cd9423',
#   'content': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.919620156288147,
#    'coordinates': {'points': [[197.91666666666666, 1700.6177978515625],
#      [197.91666666666666, 1834.7098526487086],
#      [1442.4452049466554, 1834.7098526487086],
#      [1442.4452049466554, 1700.6177978515625]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '73c2a9d151deb9c8f6b1113cb8faad74',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'c20e14a2e6cc3abd9e3794c19db89c4e',
#   'content': 'Lorem ipsum',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.8070774078369141,
#    'coordinates': {'points': [[784.7552490234375, 1314.323974609375],
#      [784.7552490234375, 1349.1657974583334],
#      [981.9907836914062, 1349.1657974583334],
#      [981.9907836914062, 1314.323974609375]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '8a137031615c0f20b771cfe3956d57f8',
#   'content': '',
#   'metadata': {'type': 'Image',
#    'links': [],
#    'coordinates': {'points': [[1202.0833333333333, 0],
#      [1202.0833333333333, 500.0],
#      [1702.0833333333333, 500.0],
#      [1702.0833333333333, 0]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'image_path': 'images/figure-1-1.jpg',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'b5906a2b13ee1bbfb62f054bd10f61f2',
#   'content': '',
#   'metadata': {'type': 'Image',
#    'links': [],
#    'coordinates': {'points': [[1452.0833333333333, 0],
#      [1452.0833333333333, 250.0],
#      [1702.0833333333333, 250.0],
#      [1702.0833333333333, 0]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'image_path': 'images/figure-2-4.jpg',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'ae823f07134a0ee9e668bef86d2caa08',
#   'content': '2',
#   'metadata': {'type': 'Header',
#    'links': [],
#    'detection_class_prob': 0.7280166149139404,
#    'coordinates': {'points': [[197.34747314453125, 132.3511505126953],
#      [197.34747314453125, 165.83247100000006],
#      [216.63411466666665, 165.83247100000006],
#      [216.63411466666665, 132.3511505126953]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '441d6021d20dac79ddd32d9e17568dc8',
#   'content': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat. Duis autem vel eum iriure dolor in hendrerit in vulputate velit esse molestie consequat, vel illum dolore eu feugiat nulla facilisis at vero eros et accumsan.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.9496526122093201,
#    'coordinates': {'points': [[197.51266479492188, 758.4445190429688],
#      [197.51266479492188, 997.2098526487088],
#      [1478.2836073864346, 997.2098526487088],
#      [1478.2836073864346, 758.4445190429688]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'parent_id': '4836a5c73aaa4ee24183d49ebc83390f',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '935fdcf8ba2e601348691f23784106a0',
#   'content': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.9381678104400635,
#    'coordinates': {'points': [[197.91666666666666, 762.22021484375],
#      [197.91666666666666, 897.2098526487088],
#      [1442.4452049466554, 897.2098526487088],
#      [1442.4452049466554, 762.22021484375]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': 'e6cd9de5667b301da81d1373f90e734c',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'e6cd9de5667b301da81d1373f90e734c',
#   'content': 'Product Overview',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.8636807203292847,
#    'coordinates': {'points': [[197.91666666666666, 666.4296875],
#      [197.91666666666666, 728.5748742500001],
#      [653.0220947265625, 728.5748742500001],
#      [653.0220947265625, 666.4296875]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'bc5e09f692d6cf4ac05d9e6d84ecf9ca',
#   'content': 'Duis autem vel eum iriure dolor in hendrerit in vulputate velit esse molestie consequat, vel illum dolore eu feugiat nulla facilisis at vero eros et accumsan.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.941511332988739,
#    'coordinates': {'points': [[785.4166666666666, 1382.915283203125],
#      [785.4166666666666, 1570.1265193153754],
#      [1451.5125732421875, 1570.1265193153754],
#      [1451.5125732421875, 1382.915283203125]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': 'c20e14a2e6cc3abd9e3794c19db89c4e',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '73c2a9d151deb9c8f6b1113cb8faad74',
#   'content': 'Dolor sit',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.8328118920326233,
#    'coordinates': {'points': [[194.70135498046875, 1617.95751953125],
#      [194.70135498046875, 1666.7118027140841],
#      [365.1525573730469, 1666.7118027140841],
#      [365.1525573730469, 1617.95751953125]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'c350ce92d1a85844e3195a7f97174afb',
#   'content': 'Nam liber tempor cum soluta nobis eleifend option congue nihil imperdiet doming id quod mazim placerat facer possim assum. Typi non habent claritatem insitam; est usus legentis in iis qui facit eorum claritatem.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.9505614638328552,
#    'coordinates': {'points': [[785.4166666666666, 1025.6669921875],
#      [785.4166666666666, 1265.9598526487086],
#      [1479.8175048828125, 1265.9598526487086],
#      [1479.8175048828125, 1025.6669921875]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '3579e20ad32d793a8dd28ff5d8023da7',
#   'content': 'Your Company',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.7488299608230591,
#    'coordinates': {'points': [[197.30868530273438, 157.51976013183594],
#      [197.30868530273438, 216.89670199424899],
#      [564.1777954101562, 216.89670199424899],
#      [564.1777954101562, 157.51976013183594]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '39324654c968eb3357caf516e5f7f294',
#   'content': 'September 04, 20XX',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.6961357593536377,
#    'coordinates': {'points': [[197.91666666666666, 541.7613525390625],
#      [197.91666666666666, 577.070965044542],
#      [477.94036865234375, 577.070965044542],
#      [477.94036865234375, 541.7613525390625]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '35ccf72b73f67342fb97284be07e0de1',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '4836a5c73aaa4ee24183d49ebc83390f',
#   'content': 'Details',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.8497405052185059,
#    'coordinates': {'points': [[191.45082092285156, 270.5783386230469],
#      [191.45082092285156, 332.7415409166668],
#      [378.80419921875, 332.7415409166668],
#      [378.80419921875, 270.5783386230469]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'parent_id': 'ae823f07134a0ee9e668bef86d2caa08',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': 'ec4e566681062b3415e6e140502beb8b',
#   'content': 'Nam liber tempor cum soluta nobis eleifend option congue nihil imperdiet doming id quod mazim placerat facer possim assum. Typi non habent claritatem insitam; est usus legentis in iis qui facit eorum claritatem. Investigationes demonstraverunt lectores legere me lius quod ii legunt saepius. Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.9483880996704102,
#    'coordinates': {'points': [[195.46563720703125, 367.3487421278755],
#      [195.46563720703125, 709.7098526487088],
#      [1489.069621816406, 709.7098526487088],
#      [1489.069621816406, 367.3487421278755]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 2,
#    'parent_id': '4836a5c73aaa4ee24183d49ebc83390f',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '002f87c6560b4f412ee064375b00319d',
#   'content': 'Lorem ipsum',
#   'metadata': {'type': 'Title',
#    'links': [],
#    'detection_class_prob': 0.8431911468505859,
#    'coordinates': {'points': [[785.4166666666666, 947.59375],
#      [785.4166666666666, 993.7951360474176],
#      [1044.846333897868, 993.7951360474176],
#      [1044.846333897868, 947.59375]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}},
#  {'_id': '80e8c329a3a621b91a31bcf97ff3334f',
#   'content': '123 Your Street Your City, ST 12345 (123) 456 - 7890',
#   'metadata': {'type': 'NarrativeText',
#    'links': [],
#    'detection_class_prob': 0.7361864447593689,
#    'coordinates': {'points': [[195.1410369873047, 247.708251953125],
#      [195.1410369873047, 343.8650176637913],
#      [445.8603210449219, 343.8650176637913],
#      [445.8603210449219, 247.708251953125]],
#     'system': 'PixelSpace',
#     'layout_width': 1700,
#     'layout_height': 2200},
#    'last_modified': '2024-11-04T19:11:07',
#    'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '3579e20ad32d793a8dd28ff5d8023da7',
#    'file_directory': './data',
#    'filename': 'sample4.pdf'}}]

# %%
from langchain_community.graph_vectorstores.links import Link

def upgrade_documents(
    vector_store: AstraDBVectorStore,
    link_function: Callable[[Document], set[Link]],
    batch_size = 10,
) -> int:
        filter = {"upgraded": {"$exists": False}}
        chunks = vector_store.metadata_search(filter=filter, n=batch_size)
        if len(chunks) == 0:
            return 0

        id_to_md_map: dict[str, dict] = {}

        for chunk in chunks:
            new_metadata["upgraded"] = True
            id_to_md_map[chunk.id] = new_metadata

        return vector_store.update_metadata(id_to_metadata=id_to_md_map)

# %%
import sys
sys.path.append("/Users/pedropacheco/Projects/demos/unstructured-platform")

from content_graph import ContentGraph  # Import after modifying the path
g = ContentGraph("Lorem Ipsum")
g.fromLangChainDocuments(
    documents=docs,
    output_image_path="./images",
    reset_graph=True,
    infer_hierarchy=True,
)
g.graph

# %%
from langchain_astradb.graph_vectorstores import AstraDBGraphVectorStore

# %%
from langchain_astradb import AstraDBVectorStore

graph_vector_store = AstraDBGraphVectorStore(
    collection_name="unstructure_elements_graph",
    embedding=embeddings,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE,
)

# %%
graph_vector_store.add_documents(g.graph)

# %%
g.graph[1].metadata["links"]
